# %% [markdown]
# # 데이터 설명
# * **작성자**: 박소희
# * **본 주피터 코드 목적**:
# * **데이터셋**: GSE111016
# * **데이터셋 설명**:
#     * Experiment type: Expression profiling by high throughput sequencing
#     * Platform: Illumina HiSeq 2500 (Homo sapiens)
#     * Experiment molecule: total RNA
#     * Sample collection:
# |연령|Type|대상자 수|
# |:--:|:--:|:--:|
# |평균 70.2세|control|20명|
# |평균 72.7세|sarcopenic|20명|
# * **참고 논문**: https://www.nature.com/articles/s41467-019-13694-1
# * **데이터셋 링크**: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE111016

# %% [markdown]
# # 라이브러리 로드

# %%
import pandas as pd

# %% [markdown]
# # 데이터 확인

# %%
# Count table 로드
gs11 = pd.read_csv('/Users/soheepark/01-RNA/Data/2_GSE111016/GSE111016_allSamplesCounts_htseqcov1_sss_forGEO.csv', index_col=0)
print(gs11.shape)
gs11.head()
# Out:
# (65217, 40)
#                  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# ENSG00000000003       124       145        61       110       122       120
# ENSG00000000005         7         6        10        16       124         9
# ENSG00000000419       536       839       415       690       825       852
# ENSG00000000457       402       538       244       486       538       549
# ENSG00000000460       141       119        73       169        96       104
#
#                  Sample 7  Sample 8  Sample 9  Sample 10  ...  Sample 31  \
# ENSG00000000003       145       118       108        125  ...        114
# ENSG00000000005        37         3         6         45  ...         70
# ENSG00000000419       774       838       629        708  ...        482
# ENSG00000000457       629       525       430        453  ...        389
# ENSG00000000460       145       115        94        131  ...        118
#
# ...

# %%
gs11
# Out:
#                  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# ENSG00000000003       124       145        61       110       122       120
# ENSG00000000005         7         6        10        16       124         9
# ENSG00000000419       536       839       415       690       825       852
# ENSG00000000457       402       538       244       486       538       549
# ENSG00000000460       141       119        73       169        96       104
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000281918        21        26        14        16        34        31
# ENSG00000281919         0         0         0         0         0         0
# ENSG00000281920         4         3         2         2         1         3
# ENSG00000281921         0         0         0         0         0         0
# ENSG00000281922         0         0         0         0         0         0
#
# ...

# %%
# Metadata 로드
gs11_meta = pd.read_csv('/Users/soheepark/01-RNA/Data/2_GSE111016/GSE111016_series_matrix.txt', sep='\t', skiprows=37, index_col=0)
gs11_meta
# Out:
#                                                                     Sample 1 [sss]  \
# !Sample_title
# !Sample_geo_accession                                                   GSM3020405
# !Sample_status                                               Public on Nov 14 2019
# !Sample_submission_date                                                Feb 22 2018
# !Sample_last_update_date                                               Nov 14 2019
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                    vastus lateralis muscle
# !Sample_organism_ch1                                                  Homo sapiens
# !Sample_characteristics_ch1                            population: Chinese descent
# !Sample_characteristics_ch1                                  sarcopenia status: no
# ...

# %%
# 그룹 특징 추출 및 개수 파악
gs11_meta.iloc[9].value_counts()
# Out:
# !Sample_characteristics_ch1
# sarcopenia status: no     20
# sarcopenia status: yes    20
# Name: count, dtype: int64

# %% [markdown]
# # 분석

# %%
gs11
# Out:
#                  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# ENSG00000000003  1.538107  1.611572       NaN  1.276717  1.401534  1.251121
# ENSG00000000005 -2.559743 -2.919183       NaN -1.483799  1.424940 -2.441664
# ENSG00000000419  3.647706  4.141844       NaN  3.922802  4.156251  4.075812
# ENSG00000000457  3.232899  3.501054       NaN  3.417402  3.539722  3.442048
# ENSG00000000460  1.723103  1.327100       NaN  1.894988  1.056646  1.045230
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000281649  4.316071  4.331632       NaN  4.317172  4.289732  4.246432
# ENSG00000281796  0.112519 -0.102416       NaN -0.327391 -0.031753 -0.362832
# ENSG00000281867 -0.363497 -0.275254       NaN -0.367722 -0.063974  0.076742
# ENSG00000281896  1.365650  1.119318       NaN  1.182100  1.100914  1.125921
# ENSG00000281918 -1.009222 -0.854987       NaN -1.483799 -0.433283 -0.691167
#
# ...
