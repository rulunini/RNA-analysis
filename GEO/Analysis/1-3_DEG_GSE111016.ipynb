# %% [markdown]
# # Introduction
# * **작성자**: 박소희
# * **본 주피터 코드 목적**: GSE111016 RNA-seq의 DEG 분석을 위함
# * **데이터셋**: GSE111016
# * **데이터셋 설명**:
#     * Experiment type: Expression profiling by high throughput sequencing
#     * Platform: Illumina HiSeq 2500 (Homo sapiens)
#     * Experiment molecule: total RNA
# * **샘플 설명**:
#     * 평균 70.2세 (control): 20명
#     * 평균 72.7세 (sarcopenic): 20명
# * **참고 논문**: https://www.nature.com/articles/s41467-019-13694-1
# * **데이터셋 링크**: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE111016

# %% [markdown]
# # Load library

# %%
import pandas as pd

import pydeseq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats
from pydeseq2.utils import load_example_data

import pickle
import os
os.chdir('/Users/soheepark/03-GEO근감소/Data/gse111016/')

# %% [markdown]
# # Data collection
# * DEG 분석을 위해 **Count table**과 샘플의 그룹 정보가 포함된 **Metadata**가 필요합니다.
# * 아래에서 **Count table**과 **Metadata table**을 불러와 형태를 확인합니다.

# %% [markdown]
# 먼저 **Count table을 확인**해봅니다.

# %%
# Count table 로드
counts = pd.read_csv('../2_GSE111016/GSE111016_allSamplesCounts_htseqcov1_sss_forGEO.csv', index_col=0)
print(counts.shape)
counts.head()
# Out:
# (65217, 40)
#                  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# ENSG00000000003       124       145        61       110       122       120
# ENSG00000000005         7         6        10        16       124         9
# ENSG00000000419       536       839       415       690       825       852
# ENSG00000000457       402       538       244       486       538       549
# ENSG00000000460       141       119        73       169        96       104
#
#                  Sample 7  Sample 8  Sample 9  Sample 10  ...  Sample 31  \
# ENSG00000000003       145       118       108        125  ...        114
# ENSG00000000005        37         3         6         45  ...         70
# ENSG00000000419       774       838       629        708  ...        482
# ENSG00000000457       629       525       430        453  ...        389
# ENSG00000000460       145       115        94        131  ...        118
#
#                  Sample 32  Sample 33  Sample 34  Sample 35  Sample 36  \
# ENSG00000000003        119         79         67        134        114
# ENSG00000000005          3          6         35          5         16
# ENSG00000000419        739        639        462        780        551
# ENSG00000000457        405        431        292        494        443
# ENSG00000000460        104        145         85        131        115
#
#                  Sample 37  Sample 38  Sample 39  Sample 40
# ENSG00000000003        106        128        149        122
# ENSG00000000005          8          6         27         18
# ENSG00000000419        576        788        742        656
# ENSG00000000457        395        551        483        438
# ENSG00000000460        141        121        125        120
#
# [5 rows x 40 columns]

# %% [markdown]
# 다음으로 **Metadata를 확인**해봅니다.

# %%
# Metadata 로드
meta = pd.read_csv('../2_GSE111016/GSE111016_series_matrix.txt', sep='\t', skiprows=37, index_col=0)
meta.head()
# Out:
#                                  Sample 1 [sss]         Sample 2 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020405             GSM3020406
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                  Sample 3 [sss]         Sample 4 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020407             GSM3020408
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                  Sample 5 [sss]         Sample 6 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020409             GSM3020410
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                  Sample 7 [sss]         Sample 8 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020411             GSM3020412
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                  Sample 9 [sss]        Sample 10 [sss]  ...  \
# !Sample_title                                                           ...
# !Sample_geo_accession                GSM3020413             GSM3020414  ...
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019  ...
# !Sample_submission_date             Feb 22 2018            Feb 22 2018  ...
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019  ...
# !Sample_type                                SRA                    SRA  ...
#
#                                 Sample 31 [sss]        Sample 32 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020435             GSM3020436
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                 Sample 33 [sss]        Sample 34 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020437             GSM3020438
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                 Sample 35 [sss]        Sample 36 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020439             GSM3020440
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                 Sample 37 [sss]        Sample 38 [sss]  \
# !Sample_title
# !Sample_geo_accession                GSM3020441             GSM3020442
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
#                                 Sample 39 [sss]        Sample 40 [sss]
# !Sample_title
# !Sample_geo_accession                GSM3020443             GSM3020444
# !Sample_status            Public on Nov 14 2019  Public on Nov 14 2019
# !Sample_submission_date             Feb 22 2018            Feb 22 2018
# !Sample_last_update_date            Nov 14 2019            Nov 14 2019
# !Sample_type                                SRA                    SRA
#
# [5 rows x 40 columns]

# %% [markdown]
# `!Sample_characteristics_ch1` 행에 **환자 그룹의 특징이 저장**되어 있습니다.

# %%
meta.loc['!Sample_characteristics_ch1']
# Out:
#                                               Sample 1 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 2 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 3 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 4 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 73
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 5 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 71
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 6 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 65
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 7 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 78
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 8 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 66
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 9 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 71
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 10 [sss]  ...  \
# !Sample_title                                                 ...
# !Sample_characteristics_ch1      population: Chinese descent  ...
# !Sample_characteristics_ch1            sarcopenia status: no  ...
# !Sample_characteristics_ch1                        Sex: male  ...
# !Sample_characteristics_ch1                     age (yr): 67  ...
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle  ...
#
#                                              Sample 31 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 78
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 32 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 79
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 33 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 74
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 34 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 35 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 36 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 74
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 37 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 78
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 38 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 65
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 39 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 68
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 40 [sss]
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 66
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
# [5 rows x 40 columns]

# %% [markdown]
# `!Sample_characteristics_ch1` 행에서 **그룹 정보가 들어간 행**을 사용할겁니다.
# 다음에서 개수를 확인해봅니다.

# %%
# 그룹 특징 추출 및 개수 파악
meta.iloc[9].value_counts()
# Out:
# sarcopenia status: no     20
# sarcopenia status: yes    20
# Name: !Sample_characteristics_ch1, dtype: int64

# %%
meta.iloc[9].head()
# Out:
# Sample 1 [sss]     sarcopenia status: no
# Sample 2 [sss]     sarcopenia status: no
# Sample 3 [sss]    sarcopenia status: yes
# Sample 4 [sss]    sarcopenia status: yes
# Sample 5 [sss]     sarcopenia status: no
# Name: !Sample_characteristics_ch1, dtype: object

# %%
# 필요한 행만 추출
val1 = pd.Series(meta.columns).apply(lambda x:x.split(' [')[0])
val2 = meta.iloc[9].apply(lambda x:x.split(': ')[-1])

# no, yes -> oh(old health), os(old sarcopenia)
my_dict = {'no':'OH', 'yes':'OS'}
val2 = val2.map(my_dict)

metadata = dict(zip(val1, val2))
metadata = pd.DataFrame.from_dict(metadata, orient='index')
metadata.rename(columns = {metadata.columns[0]:'Condition'}, inplace=True)
metadata['Sample'] = metadata.index
metadata['Temp'] = metadata['Sample'].apply(lambda x:x.split(' ')[-1])
metadata.head()
# Out:
#          Condition    Sample Temp
# Sample 1        OH  Sample 1    1
# Sample 2        OH  Sample 2    2
# Sample 3        OS  Sample 3    3
# Sample 4        OS  Sample 4    4
# Sample 5        OH  Sample 5    5

# %%
metadata[metadata['Sample'].isin(['Sample 3', 'Sample 16', 'Sample 17', 'Sample 24', 'Sample 27', 'Sample 28', 'Sample 31'])]
# Out:
#           Condition     Sample Temp
# Sample 3         OS   Sample 3    3
# Sample 16        OS  Sample 16   16
# Sample 17        OH  Sample 17   17
# Sample 24        OH  Sample 24   24
# Sample 27        OH  Sample 27   27
# Sample 28        OS  Sample 28   28
# Sample 31        OS  Sample 31   31

# %% [markdown]
# # Extract metadata for EDA

# %%
meta.loc['!Sample_characteristics_ch1']
# Out:
#                                               Sample 1 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 2 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 3 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 4 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 73
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 5 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 71
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 6 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 65
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 7 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 78
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 8 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 66
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                               Sample 9 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 71
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 10 [sss]  ...  \
# !Sample_title                                                 ...
# !Sample_characteristics_ch1      population: Chinese descent  ...
# !Sample_characteristics_ch1            sarcopenia status: no  ...
# !Sample_characteristics_ch1                        Sex: male  ...
# !Sample_characteristics_ch1                     age (yr): 67  ...
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle  ...
#
#                                              Sample 31 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 78
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 32 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 79
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 33 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 74
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 34 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 35 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 69
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 36 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 74
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 37 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 78
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 38 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1            sarcopenia status: no
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 65
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 39 [sss]  \
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 68
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
#                                              Sample 40 [sss]
# !Sample_title
# !Sample_characteristics_ch1      population: Chinese descent
# !Sample_characteristics_ch1           sarcopenia status: yes
# !Sample_characteristics_ch1                        Sex: male
# !Sample_characteristics_ch1                     age (yr): 66
# !Sample_characteristics_ch1  tissue: vastus lateralis muscle
#
# [5 rows x 40 columns]

# %%
eda = {}
for i in range(0,5):
    key = meta.loc['!Sample_characteristics_ch1'].iloc[i][0].split(': ')[0]
    value = meta.loc['!Sample_characteristics_ch1'].iloc[i]
    value = value.apply(lambda x:x.split(': ')[-1])
    eda[key] = value

eda = pd.DataFrame(eda)

# %%
eda.head()
# Out:
#                      population sarcopenia status   Sex age (yr)  \
# Sample 1 [sss]  Chinese descent                no  male       69
# Sample 2 [sss]  Chinese descent                no  male       69
# Sample 3 [sss]  Chinese descent               yes  male       69
# Sample 4 [sss]  Chinese descent               yes  male       73
# Sample 5 [sss]  Chinese descent                no  male       71
#
#                                  tissue
# Sample 1 [sss]  vastus lateralis muscle
# Sample 2 [sss]  vastus lateralis muscle
# Sample 3 [sss]  vastus lateralis muscle
# Sample 4 [sss]  vastus lateralis muscle
# Sample 5 [sss]  vastus lateralis muscle

# %%
# eda.to_csv('./GSE111016_eda.csv')

# %% [markdown]
# # Preprocessing
# 다음은 유전자를 **Ensembl**에서 **GeneSymbol**로 바꿔주는 과정입니다.
# GSE111016에서 유전자는 **Ensembl**로 저장되어 있으며 GSE167186과 병합을 위해 다음 과정이 필요합니다.

# %% [markdown]
# ## Ensembl to Symbol (by supplementary data 2)

# %%
supple = pd.read_csv('/Users/soheepark/03-GEO근감소/Data/GSE111016_SupplementaryDataset2.csv', index_col=0)
supple[:3]
# Out:
#                 chr     gene_source     start       end strand  gene_version  \
# ENSG00000214973   1          havana  27200834  27201473      -             3
# ENSG00000130312  19  ensembl_havana  17292609  17306843      +             5
# ENSG00000250479  22  ensembl_havana  23765834  23768443      -             7
#
#                 gene_name          gene_biotype symbol.org.Hs.eg  \
# ENSG00000214973  CHCHD3P3  processed_pseudogene              NaN
# ENSG00000130312    MRPL34        protein_coding           MRPL34
# ENSG00000250479   CHCHD10        protein_coding              NaN
#
#                                      title.org.Hs.eg  Amean  coef_sarc  \
# ENSG00000214973                                  NaN  2.246     -0.323
# ENSG00000130312  mitochondrial ribosomal protein L34  4.219     -0.373
# ENSG00000250479                                  NaN  6.602     -0.337
#
#                  modt_sarc  pval_sarc  adjp_sarc
# ENSG00000214973     -5.154   0.000007     0.0796
# ENSG00000130312     -4.914   0.000015     0.0796
# ENSG00000250479     -4.843   0.000018     0.0796

# %%
# counts 인덱스에 맞는 Supple Genesymbol을 매핑

counts['GeneSymbol'] = counts.index.map(supple['gene_name'])
print(f'Count of rows: {counts.shape[0]}')
counts.head()
# Out:
# Count of rows: 65217
#                  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# ENSG00000000003       124       145        61       110       122       120
# ENSG00000000005         7         6        10        16       124         9
# ENSG00000000419       536       839       415       690       825       852
# ENSG00000000457       402       538       244       486       538       549
# ENSG00000000460       141       119        73       169        96       104
#
#                  Sample 7  Sample 8  Sample 9  Sample 10  ...  Sample 32  \
# ENSG00000000003       145       118       108        125  ...        119
# ENSG00000000005        37         3         6         45  ...          3
# ENSG00000000419       774       838       629        708  ...        739
# ENSG00000000457       629       525       430        453  ...        405
# ENSG00000000460       145       115        94        131  ...        104
#
#                  Sample 33  Sample 34  Sample 35  Sample 36  Sample 37  \
# ENSG00000000003         79         67        134        114        106
# ENSG00000000005          6         35          5         16          8
# ENSG00000000419        639        462        780        551        576
# ENSG00000000457        431        292        494        443        395
# ENSG00000000460        145         85        131        115        141
#
#                  Sample 38  Sample 39  Sample 40  GeneSymbol
# ENSG00000000003        128        149        122      TSPAN6
# ENSG00000000005          6         27         18        TNMD
# ENSG00000000419        788        742        656        DPM1
# ENSG00000000457        551        483        438       SCYL3
# ENSG00000000460        121        125        120    C1orf112
#
# [5 rows x 41 columns]

# %%
# Gene Symbol이 없는 EnsembleID는 삭제
print(f"Count of NA GeneSymbol {counts['GeneSymbol'].isna().sum()}")
counts.dropna(subset=['GeneSymbol'], inplace=True)
print(f'Count of rows: {counts.shape[0]}')
# Out:
# Count of NA GeneSymbol 48338
# Count of rows: 16879

# %% [markdown]
# ## Ensembl to Symbol (by supplementary dataset 2)

# %%
supple = pd.read_csv('/Users/soheepark/03-GEO근감소/Data/GSE111016_SupplementaryDataset2.csv', index_col=0)
supple.head()
# Out:
#                 chr     gene_source      start        end strand  \
# ENSG00000214973   1          havana   27200834   27201473      -
# ENSG00000130312  19  ensembl_havana   17292609   17306843      +
# ENSG00000250479  22  ensembl_havana   23765834   23768443      -
# ENSG00000156411  14  ensembl_havana  103912288  103928269      -
# ENSG00000146147   6  ensembl_havana   53929982   54266280      +
#
#                  gene_version gene_name          gene_biotype  \
# ENSG00000214973             3  CHCHD3P3  processed_pseudogene
# ENSG00000130312             5    MRPL34        protein_coding
# ENSG00000250479             7   CHCHD10        protein_coding
# ENSG00000156411             8   C14orf2        protein_coding
# ENSG00000146147            13      MLIP        protein_coding
#
#                 symbol.org.Hs.eg                      title.org.Hs.eg  Amean  \
# ENSG00000214973              NaN                                  NaN  2.246
# ENSG00000130312           MRPL34  mitochondrial ribosomal protein L34  4.219
# ENSG00000250479              NaN                                  NaN  6.602
# ENSG00000156411          C14orf2   chromosome 14 open reading frame 2  5.394
# ENSG00000146147             MLIP    muscular LMNA interacting protein  6.833
#
#                  coef_sarc  modt_sarc  pval_sarc  adjp_sarc
# ENSG00000214973     -0.323     -5.154   0.000007     0.0796
# ENSG00000130312     -0.373     -4.914   0.000015     0.0796
# ENSG00000250479     -0.337     -4.843   0.000018     0.0796
# ENSG00000156411     -0.302     -4.765   0.000024     0.0796
# ENSG00000146147      0.277      4.714   0.000028     0.0796

# %%
# counts 인덱스에 맞는 supple의 gene_name을 매핑

counts['GeneSymbol'] = counts.index.map(supple.gene_name)
print(f'Count of rows: {counts.shape[0]}')
# Out:
# Count of rows: 65217

# %%
# Gene Symbol이 na인 경우 삭제
print(f"NA counts of GeneSymbol: {counts['GeneSymbol'].isna().sum()}")
counts.dropna(subset=['GeneSymbol'], inplace=True)
print(f'Count of rows: {counts.shape[0]}')
# Out:
# NA counts of GeneSymbol: 48338
# Count of rows: 16879

# %%
# 'GeneSymbol' 컬럼을 인덱스로 설정하고 'EnsembleID' 컬럼 삭제

counts.set_index('GeneSymbol', inplace=True)
print(f'The shape of counts table: {counts.shape}')

# %%
# 전체 샘플에서 발현량이 없는 유전자를 필터링합니다.
print(f'필터링 전 테이블: {counts.shape}')
counts = counts.loc[counts.sum(axis=1)>0]
print(f'필터링 후 테이블: {counts.shape}')

# %% [markdown]
# ## Ensembl to Symbol (by pybiomart)
# * https://pypi.org/project/pybiomart/

# %%
# # pip install pybiomart
# # http://www.ensembl.org/biomart
# from pybiomart import Server

# server = Server(host='http://www.ensembl.org')

# dataset = (server.marts['ENSEMBL_MART_ENSEMBL']
#                  .datasets['hsapiens_gene_ensembl'])

# dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'],
#               filters={'chromosome_name': ['1','2']}).head()
# Out:
#     Gene stable ID    Gene name
# 0  ENSG00000290825      DDX11L2
# 1  ENSG00000223972      DDX11L1
# 2  ENSG00000227232       WASH7P
# 3  ENSG00000278267    MIR6859-1
# 4  ENSG00000243485  MIR1302-2HG

# %%
# from pybiomart import Dataset

# dataset = Dataset(name='hsapiens_gene_ensembl',
#                   host='http://www.ensembl.org')

# dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'],
#               filters={'chromosome_name': ['1','2']}).head()
# Out:
#     Gene stable ID    Gene name
# 0  ENSG00000290825      DDX11L2
# 1  ENSG00000223972      DDX11L1
# 2  ENSG00000227232       WASH7P
# 3  ENSG00000278267    MIR6859-1
# 4  ENSG00000243485  MIR1302-2HG

# %% [markdown]
# ## Ensembl to Symbol (by biomart)

# %%
# pip install biomart
# Original reference: https://github.com/sebriois/biomart
# Reference blog: https://autobencoder.com/2021-10-03-gene-conversion/
# Reference 2: https://bioconductor.riken.jp/packages/3.4/bioc/vignettes/biomaRt/inst/doc/biomaRt.html

import biomart

def get_ensembl_mappings():                                   
    # 서버 연결 세팅
    server = biomart.BiomartServer('http://www.ensembl.org/biomart')         
    mart = server.datasets['hsapiens_gene_ensembl']                            

    # 원하는 타입의 어노테이션을 작성
    attributes = ['ensembl_gene_id', 'hgnc_symbol'] # ensembl_transcript_id

    # 매핑
    response = mart.search({'attributes': attributes})                          
    data = response.raw.data.decode('ascii')                                    

    # 딕셔너리에 저장
    ensembl_to_genesymbol = {}                                                  
    for line in data.splitlines():                                              
        line = line.split('\t')                                                 

        ensembl_gene = line[0]
        gene_symbol = line[1]

        ensembl_to_genesymbol[ensembl_gene] = ensembl_gene
        ensembl_to_genesymbol[ensembl_gene] = gene_symbol

        
    return ensembl_to_genesymbol

# %%
# ensemble genesymbol 매핑 데이터프레임 생성

map_dict = get_ensembl_mappings()
map_dict
# Out:
# {'ENSG00000210049': 'MT-TF',
#  'ENSG00000211459': 'MT-RNR1',
#  'ENSG00000210077': 'MT-TV',
#  'ENSG00000210082': 'MT-RNR2',
#  'ENSG00000209082': 'MT-TL1',
#  'ENSG00000198888': 'MT-ND1',
#  'ENSG00000210100': 'MT-TI',
#  'ENSG00000210107': 'MT-TQ',
#  'ENSG00000210112': 'MT-TM',
#  'ENSG00000198763': 'MT-ND2',
#  'ENSG00000210117': 'MT-TW',
#  'ENSG00000210127': 'MT-TA',
#  'ENSG00000210135': 'MT-TN',
#  'ENSG00000210140': 'MT-TC',
#  'ENSG00000210144': 'MT-TY',
#  'ENSG00000198804': 'MT-CO1',
#  'ENSG00000210151': 'MT-TS1',
#  'ENSG00000210154': 'MT-TD',
#  'ENSG00000198712': 'MT-CO2',
#  'ENSG00000210156': 'MT-TK',
#  'ENSG00000228253': 'MT-ATP8',
#  'ENSG00000198899': 'MT-ATP6',
#  'ENSG00000198938': 'MT-CO3',
#  'ENSG00000210164': 'MT-TG',
#  'ENSG00000198840': 'MT-ND3',
#  'ENSG00000210174': 'MT-TR',
#  'ENSG00000212907': 'MT-ND4L',
#  'ENSG00000198886': 'MT-ND4',
#  'ENSG00000210176': 'MT-TH',
#  'ENSG00000210184': 'MT-TS2',
#  'ENSG00000210191': 'MT-TL2',
#  'ENSG00000198786': 'MT-ND5',
#  'ENSG00000198695': 'MT-ND6',
#  'ENSG00000210194': 'MT-TE',
#  'ENSG00000198727': 'MT-CYB',
#  'ENSG00000210195': 'MT-TT',
#  'ENSG00000210196': 'MT-TP',
#  'ENSG00000271254': '',
#  'ENSG00000278625': '',
#  'ENSG00000278457': '',
#  'ENSG00000276197': '',
#  'ENSG00000277428': '',
#  'ENSG00000278573': '',
#  'ENSG00000278704': '',
#  'ENSG00000273748': '',
#  'ENSG00000275661': '',
#  'ENSG00000274202': '',
#  'ENSG00000277630': '',
#  'ENSG00000277400': '',
#  'ENSG00000274917': 'RNA5-8SN5',
#  'ENSG00000278294': '',
#  'ENSG00000276256': '',
#  'ENSG00000277196': '',
#  'ENSG00000276351': '',
#  'ENSG00000274847': 'MAFIP',
#  'ENSG00000273730': '',
#  'ENSG00000273937': '',
#  'ENSG00000276345': '',
#  'ENSG00000273532': '',
#  'ENSG00000278793': '',
#  'ENSG00000276932': '',
#  'ENSG00000278817': '',
#  'ENSG00000276711': '',
#  'ENSG00000276017': '',
#  'ENSG00000278633': '',
#  'ENSG00000278066': '',
#  'ENSG00000276312': '',
#  'ENSG00000276700': 'RNA5-8SN4',
#  'ENSG00000275757': '',
#  'ENSG00000273739': '',
#  'ENSG00000275063': '',
#  'ENSG00000277856': '',
#  'ENSG00000277374': '',
#  'ENSG00000291360': 'RPL23AP45',
#  'ENSG00000278384': '',
#  'ENSG00000278673': '',
#  'ENSG00000275987': '',
#  'ENSG00000277890': '',
#  'ENSG00000268674': '',
#  'ENSG00000275249': '',
#  'ENSG00000277475': '',
#  'ENSG00000275405': '',
#  'ENSG00000274792': '',
#  'ENSG00000276872': '',
#  'ENSG00000276760': '',
#  'ENSG00000277927': '',
#  'ENSG00000291371': '',
#  'ENSG00000291372': 'RNU6-409P',
#  'ENSG00000291368': 'ACR',
#  'ENSG00000291369': '',
#  'ENSG00000291370': '',
#  'ENSG00000292254': '',
#  'ENSG00000274175': '',
#  'ENSG00000273554': '',
#  'ENSG00000275869': '',
#  'ENSG00000278510': '',
#  'ENSG00000273843': '',
#  'ENSG00000277836': '',
#  'ENSG00000291410': '',
#  'ENSG00000291411': '',
#  'ENSG00000291412': '',
#  'ENSG00000291413': '',
#  'ENSG00000291414': 'MIR4740',
#  'ENSG00000291415': 'MIR3186',
#  'ENSG00000291416': '',
#  'ENSG00000291417': 'LINC01971',
#  'ENSG00000291418': '',
#  'ENSG00000291420': 'ACTG1',
#  'ENSG00000288522': '',
#  'ENSG00000288204': 'HMX1',
#  'ENSG00000288247': '',
#  'ENSG00000291421': 'BAHCC1',
#  'ENSG00000291422': '',
#  'ENSG00000291423': '',
#  'ENSG00000291424': '',
#  'ENSG00000291425': 'LINC03048',
#  'ENSG00000288372': '',
#  'ENSG00000288288': '',
#  'ENSG00000288129': '',
#  'ENSG00000288472': 'LINC03015',
#  'ENSG00000288417': 'LINC03014',
#  'ENSG00000288502': '',
#  'ENSG00000288311': '',
#  'ENSG00000288449': '',
#  'ENSG00000288499': 'FAM20C',
#  'ENSG00000288159': '',
#  'ENSG00000288431': '',
#  'ENSG00000281819': 'NAA50P1',
#  'ENSG00000263150': 'OR8J2',
#  'ENSG00000262851': 'OR5T2',
#  'ENSG00000261897': 'OR5T3',
#  'ENSG00000262784': 'OR5T1',
#  'ENSG00000262611': 'OR8H1',
#  'ENSG00000280712': 'OR8I1P',
#  'ENSG00000262755': 'OR8K3',
#  'ENSG00000281773': 'FAM8A2P',
#  'ENSG00000280617': 'OR8K2P',
#  'ENSG00000263328': 'OR8K1',
#  'ENSG00000281820': 'RPL5P29',
#  'ENSG00000262796': 'OR8J1',
#  'ENSG00000262315': 'OR8U8',
#  'ENSG00000281038': 'OR8U9',
#  'ENSG00000280577': 'OR8L1P',
#  'ENSG00000288269': 'GCGR',
#  'ENSG00000288213': 'MCRIP1',
#  'ENSG00000288319': '',
#  'ENSG00000288521': '',
#  'ENSG00000288394': 'ABCD1P4',
#  'ENSG00000288228': '',
#  'ENSG00000288342': 'PABPC1P9',
#  'ENSG00000288315': 'SLC9B1P4',
#  'ENSG00000288272': 'ACTR3BP6',
#  'ENSG00000288186': 'PPP1R27',
#  'ENSG00000282162': 'LINC01784',
#  'ENSG00000281934': 'PRAMEF11',
#  'ENSG00000282116': 'PRAMEF30P',
#  'ENSG00000282175': 'HNRNPCL1',
#  'ENSG00000282817': 'PRAMEF2',
#  'ENSG00000282584': 'PRAMEF4',
#  'ENSG00000282663': 'PRAMEF10',
#  'ENSG00000279195': 'PRAMEF7',
#  'ENSG00000282338': 'RNU6-1072P',
#  'ENSG00000282549': 'PRAMEF29P',
#  'ENSG00000282119': 'PRAMEF6',
#  'ENSG00000282791': 'PRAMEF28P',
#  'ENSG00000282437': 'PRAMEF27',
#  'ENSG00000282559': 'HNRNPCL3',
#  'ENSG00000282566': 'PRAMEF25',
#  'ENSG00000282258': 'PRAMEF34P',
#  'ENSG00000282562': 'PRAMEF35P',
#  'ENSG00000282530': 'HNRNPCL2',
#  'ENSG00000282468': 'PRAMEF36P',
#  'ENSG00000290624': '',
#  'ENSG00000282341': '',
#  'ENSG00000281987': 'PRAMEF26',
#  'ENSG00000290500': '',
#  'ENSG00000282095': 'HNRNPCL4',
#  'ENSG00000261958': 'OR9G1',
#  'ENSG00000282298': 'PRAMEF9',
#  'ENSG00000262191': 'OR9G9',
#  'ENSG00000281683': '',
#  'ENSG00000282741': 'PRAMEF13',
#  'ENSG00000262268': 'OR9G3P',
#  'ENSG00000262647': 'OR9G4',
#  'ENSG00000282212': 'PRAMEF18',
#  'ENSG00000281777': 'OR9G2P',
#  'ENSG00000282289': 'PRAMEF31P',
#  'ENSG00000282424': 'PRAMEF5',
#  'ENSG00000281313': 'OR5G1P',
#  'ENSG00000281279': 'OR5G4P',
#  'ENSG00000282216': 'PRAMEF32P',
#  'ENSG00000282288': 'RNU6-771P',
#  'ENSG00000262535': 'OR5G5P',
#  'ENSG00000282583': 'PRAMEF8',
#  'ENSG00000281107': 'OR5G3',
#  'ENSG00000281839': 'LINC02735',
#  'ENSG00000282125': 'PRAMEF33',
#  'ENSG00000293551': 'PRAMEF22',
#  'ENSG00000291378': 'ARHGEF19-AS1',
#  'ENSG00000291381': 'ARHGEF19',
#  'ENSG00000291405': '',
#  'ENSG00000288263': 'GRK1',
#  'ENSG00000291404': 'ANO7L1',
#  'ENSG00000291376': '',
#  'ENSG00000291382': 'CPLANE2',
#  'ENSG00000288305': 'LINC00552',
#  'ENSG00000291377': 'MT1XP1',
#  'ENSG00000291375': 'FBXO42',
#  'ENSG00000291379': 'SZRD1',
#  'ENSG00000291374': 'RPL22P3',
#  'ENSG00000291401': 'SPATA21',
#  'ENSG00000291380': 'NECAP2',
#  'ENSG00000291388': 'LINC01772',
#  'ENSG00000291402': 'CROCCP3',
#  'ENSG00000291389': 'RNU1-1',
#  'ENSG00000291390': '',
#  'ENSG00000291391': '',
#  'ENSG00000291392': 'LINC01783',
#  'ENSG00000291393': 'RNU1-6P',
#  'ENSG00000291394': 'PDE4DIPP8',
#  'ENSG00000291386': '',
#  'ENSG00000291385': 'RNU1-2',
#  'ENSG00000291408': '',
#  'ENSG00000291384': '',
#  'ENSG00000291400': '',
#  'ENSG00000291383': 'RNU1-5P',
#  'ENSG00000291395': '',
#  'ENSG00000291397': '',
#  'ENSG00000291398': 'EIF1AXP1',
#  'ENSG00000291396': 'RNU1-3',
#  'ENSG00000291399': 'RNU1-4',
#  'ENSG00000291387': 'PADI2',
#  'ENSG00000292230': '',
#  'ENSG00000291403': 'CROCCP4',
#  'ENSG00000292231': '',
#  'ENSG00000291407': '',
#  'ENSG00000292235': '',
#  'ENSG00000292236': '',
#  'ENSG00000292238': '',
#  'ENSG00000292239': '',
#  'ENSG00000292240': '',
#  'ENSG00000292241': '',
#  'ENSG00000292242': '',
#  'ENSG00000292229': '',
#  'ENSG00000291426': 'TOLLIP',
#  'ENSG00000292226': '',
#  'ENSG00000292228': '',
#  'ENSG00000291427': 'TOLLIP-DT',
#  'ENSG00000291429': '',
#  'ENSG00000291430': 'LINC02689',
#  'ENSG00000291428': 'BRSK2',
#  'ENSG00000292227': '',
#  'ENSG00000292225': 'NBPF1',
#  'ENSG00000291441': '',
#  'ENSG00000291431': 'DUSP8',
#  'ENSG00000291432': 'KRTAP5-AS1',
#  'ENSG00000291433': 'KRTAP5-1',
#  'ENSG00000291434': 'KRTAP5-2',
#  'ENSG00000291435': 'KRTAP5-3',
#  'ENSG00000291440': 'KRTAP5-4',
#  'ENSG00000291443': 'KRTAP5-5',
#  'ENSG00000291436': '',
#  'ENSG00000291437': 'FAM99A',
#  'ENSG00000291438': 'FAM99B',
#  'ENSG00000291439': 'LINC02708',
#  'ENSG00000291442': 'MOB2',
#  'ENSG00000291444': 'RBMY3AP',
#  'ENSG00000291445': 'CDY3P',
#  'ENSG00000291446': 'TSPY25P',
#  'ENSG00000291447': 'USP9YP22',
#  'ENSG00000291448': 'TSPY16P',
#  'ENSG00000291449': 'USP9YP4',
#  'ENSG00000291450': 'ELOCP4',
#  'ENSG00000291451': 'RBMY1A3P',
#  'ENSG00000291452': '',
#  'ENSG00000291453': 'TTTY20',
#  'ENSG00000291455': 'TSPY8',
#  'ENSG00000291456': 'FAM197Y7',
#  'ENSG00000291457': '',
#  'ENSG00000291458': 'TSPY4',
#  'ENSG00000291459': 'TSPY9',
#  'ENSG00000291460': 'FAM197Y2',
#  'ENSG00000291461': 'FAM197Y4',
#  'ENSG00000291462': 'FAM197Y4',
#  'ENSG00000291454': 'FAM197Y8',
#  'ENSG00000293355': 'FAM197Y8',
#  'ENSG00000281449': 'BCL2L14',
#  'ENSG00000285019': 'ELOCP5',
#  'ENSG00000285196': 'CDY10P',
#  'ENSG00000285308': 'USP9YP3',
#  'ENSG00000281442': 'PTMAP9',
#  'ENSG00000283344': 'MIR1244-4',
#  'ENSG00000281324': 'LRP6',
#  'ENSG00000285028': 'USP9YP8',
#  'ENSG00000285455': 'CDY11P',
#  'ENSG00000285477': 'OFD1P16Y',
#  'ENSG00000280475': 'RPL21P100',
#  'ENSG00000206783': 'RNU6-545P',
#  'ENSG00000281874': '',
#  'ENSG00000207477': 'RNU6-318P',
#  'ENSG00000281818': 'MANSC1',
#  'ENSG00000281051': 'RPL23AP66',
#  'ENSG00000281234': 'LOH12CR2',
#  'ENSG00000280689': 'BORCS5',
#  'ENSG00000281168': '',
#  'ENSG00000280962': 'DUSP16',
#  'ENSG00000281671': '',
#  'ENSG00000281525': '',
#  'ENSG00000282467': '',
#  'ENSG00000292327': 'PPP2R3B',
#  'ENSG00000292328': 'RPL14P5',
#  'ENSG00000292329': '',
#  'ENSG00000292330': '',
#  'ENSG00000292331': 'ASMTL-AS1',
#  'ENSG00000292332': 'IL3RA',
#  'ENSG00000292333': 'P2RY8',
#  'ENSG00000292334': 'SLC25A6',
#  'ENSG00000292335': '',
#  'ENSG00000292336': 'ASMT',
#  'ENSG00000292337': 'DHRSX-IT1',
#  'ENSG00000288406': '',
#  'ENSG00000292338': 'DHRSX',
#  'ENSG00000292339': 'ASMTL',
#  'ENSG00000292340': 'LINC02968',
#  'ENSG00000292341': 'LINC00106',
#  'ENSG00000292342': 'LINC00685',
#  'ENSG00000292343': 'AKAP17A',
#  'ENSG00000292344': 'PLCXD1',
#  'ENSG00000292345': 'ZBED1',
#  'ENSG00000292346': 'MIR6089',
#  'ENSG00000292347': 'LINC00102',
#  'ENSG00000292348': 'CD99',
#  'ENSG00000292349': '',
#  'ENSG00000292350': '',
#  'ENSG00000292351': '',
#  'ENSG00000292352': 'FABP5P13',
#  'ENSG00000292353': 'KRT18P53',
#  'ENSG00000292354': 'SHOX',
#  'ENSG00000292355': 'MIR3690',
#  'ENSG00000292356': 'RNA5SP498',
#  'ENSG00000292357': 'CSF2RA',
#  'ENSG00000292358': 'GTPBP6',
#  'ENSG00000292359': '',
#  'ENSG00000292360': 'LINC03112',
#  'ENSG00000292361': 'CD99P1',
#  'ENSG00000292362': 'CD99P1',
#  'ENSG00000292363': 'CRLF2',
#  'ENSG00000292364': 'AMD1P2',
#  'ENSG00000292365': 'DPH3P2',
#  'ENSG00000292366': 'VAMP7',
#  'ENSG00000292367': 'ELOCP24',
#  'ENSG00000292368': 'TRPC6P1',
#  'ENSG00000292369': '',
#  'ENSG00000292370': 'WASIR1',
#  'ENSG00000292371': 'DDX11L16',
#  'ENSG00000292372': 'WASH6P',
#  'ENSG00000292373': 'IL9R',
#  'ENSG00000215601': 'TSPY24P',
#  'ENSG00000215603': 'ZNF92P1Y',
#  'ENSG00000225878': 'SERBP1P2',
#  'ENSG00000236435': 'TSPY12P',
#  'ENSG00000258991': 'DUX4L19',
#  'ENSG00000237048': 'TTTY12',
#  'ENSG00000224518': '',
#  'ENSG00000231988': 'OFD1P3Y',
#  'ENSG00000238073': 'RBMY2HP',
#  'ENSG00000275866': '',
#  'ENSG00000131538': 'TTTY6',
#  'ENSG00000271595': 'ELOCP35',
#  'ENSG00000183704': 'SLC9B1P1',
#  'ENSG00000232927': 'USP12PY',
#  'ENSG00000277438': 'KDM5DP1',
#  'ENSG00000286217': 'LINC00279',
#  'ENSG00000259154': 'DUX4L17',
#  'ENSG00000169789': 'PRY',
#  'ENSG00000273589': '',
#  'ENSG00000273863': '',
#  'ENSG00000228571': 'HSFY7P',
#  'ENSG00000288260': '',
#  'ENSG00000271375': '',
#  'ENSG00000224634': 'ZNF736P6Y',
#  'ENSG00000285470': 'TUSC2P1',
#  'ENSG00000288430': 'RNU5B-4P',
#  'ENSG00000226092': 'RBMY2AP',
#  'ENSG00000288297': 'ECSCR',
#  'ENSG00000234620': 'PUDPP1',
#  'ENSG00000236690': '',
#  'ENSG00000273693': 'CDRT15P10',
#  'ENSG00000114374': 'USP9Y',
#  'ENSG00000288274': 'SMIM33',
#  'ENSG00000288243': 'STING1',
#  'ENSG00000288388': '',
#  'ENSG00000288138': 'NCOA4P4',
#  'ENSG00000169807': 'PRY2',
#  'ENSG00000223422': '',
#  'ENSG00000231159': 'OFD1P8Y',
#  'ENSG00000225653': 'RNF19BPY',
#  'ENSG00000251618': '',
#  'ENSG00000229159': 'TSPY23P',
#  'ENSG00000228578': 'TUBB1P2',
#  'ENSG00000275280': '',
#  'ENSG00000270242': 'ACTR3BP1',
#  'ENSG00000236477': 'RPS24P1',
#  'ENSG00000237997': 'RCC2P2',
#  'ENSG00000244246': 'ZNF736P8Y',
#  'ENSG00000198692': 'EIF1AY',
#  'ENSG00000183753': 'BPY2',
#  'ENSG00000225433': 'MTND1P12',
#  'ENSG00000227166': 'STSP1',
#  'ENSG00000235857': 'CTBP2P1',
#  'ENSG00000223955': 'MTND6P1',
#  'ENSG00000270455': 'PABPC1P5',
#  'ENSG00000229940': 'TSPY22P',
#  'ENSG00000234385': 'RCC2P1',
#  'ENSG00000226863': 'SHROOM2P1',
#  'ENSG00000237968': '',
#  'ENSG00000233699': 'TTTY18',
#  'ENSG00000286009': '',
#  'ENSG00000271365': '',
#  'ENSG00000259029': 'DUX4L18',
#  'ENSG00000286201': '',
#  'ENSG00000215537': 'ZNF736P11Y',
#  'ENSG00000230476': 'OFD1P9Y',
#  'ENSG00000229745': 'BPY2DP',
#  'ENSG00000227204': 'RBMY2JP',
#  'ENSG00000275828': 'CHEK2P1',
#  'ENSG00000225615': 'RBMY2UP',
#  'ENSG00000230663': 'FAM224B',
#  'ENSG00000232522': 'ZNF886P',
#  'ENSG00000234131': 'ELOCP8',
#  'ENSG00000277519': 'OFD1P16Y',
#  'ENSG00000259247': 'TTTY25P',
#  'ENSG00000273731': '',
#  'ENSG00000236951': '',
#  'ENSG00000215583': 'ASS1P6',
#  'ENSG00000274162': 'SNX18P1Y',
#  'ENSG00000227444': '',
#  'ENSG00000233774': 'MED14P1',
#  'ENSG00000232475': 'HSFY5P',
#  'ENSG00000228764': 'ZNF885P',
#  'ENSG00000232226': 'ARSFP1',
#  'ENSG00000224567': '',
#  'ENSG00000241200': 'ZNF736P7Y',
#  'ENSG00000228518': 'SURF6P1',
#  'ENSG00000227447': 'XGY1',
#  'ENSG00000274231': '',
#  'ENSG00000286050': '',
#  'ENSG00000274502': 'ANKRD20A6P',
#  'ENSG00000278854': '',
#  'ENSG00000225809': 'RBMY2KP',
#  'ENSG00000237902': 'TSPY21P',
#  'ENSG00000232419': 'TTTY19',
#  'ENSG00000226906': 'TTTY4',
#  'ENSG00000230025': '',
#  'ENSG00000235649': 'MXRA5Y',
#  'ENSG00000258567': 'DUX4L16',
#  'ENSG00000234179': 'MTCYBP1',
#  'ENSG00000271309': '',
#  'ENSG00000229553': 'USP9YP17',
#  'ENSG00000228240': 'TTTY17A',
#  'ENSG00000234652': 'AGPAT5P1',
#  'ENSG00000218410': '',
#  'ENSG00000224989': 'FAM41AY1',
#  'ENSG00000131548': 'TTTY6B',
#  'ENSG00000232029': 'ELOCP15',
#  'ENSG00000273858': '',
#  'ENSG00000227830': 'TRIM60P3Y',
#  'ENSG00000226529': 'MTND1P1',
#  'ENSG00000274837': '',
#  'ENSG00000216777': 'PRRC2CP1',
#  'ENSG00000216824': 'ZNF736P10Y',
#  'ENSG00000276829': '',
#  'ENSG00000228850': 'CDY12P',
#  'ENSG00000283076': '',
#  'ENSG00000234850': 'MTND2P3',
#  'ENSG00000224873': 'CDY13P',
#  'ENSG00000229234': 'RBMY1KP',
#  'ENSG00000270570': '',
#  'ENSG00000223517': '',
#  'ENSG00000228207': '',
#  'ENSG00000224917': '',
#  'ENSG00000286187': '',
#  'ENSG00000225117': 'ARSDP1',
#  'ENSG00000215560': 'TTTY5',
#  'ENSG00000228411': 'CDY4P',
#  'ENSG00000235059': '',
#  'ENSG00000244395': 'RBMY1D',
#  'ENSG00000230727': 'RBMY2WP',
#  'ENSG00000230814': 'USP9YP24',
#  'ENSG00000229725': '',
#  'ENSG00000229236': 'TTTY10',
#  'ENSG00000229518': 'UBE2V1P3',
#  'ENSG00000232730': 'FAM8A4P',
#  'ENSG00000229308': '',
#  'ENSG00000244000': '',
#  'ENSG00000232764': 'TRIM60P8Y',
#  'ENSG00000236131': 'MED13P1',
#  'ENSG00000227949': 'CYCSP46',
#  'ENSG00000252900': 'RNU6-303P',
#  'ENSG00000252689': '',
#  'ENSG00000243980': 'RN7SL702P',
#  'ENSG00000252315': 'RNA5SP520',
#  'ENSG00000252012': 'RNA5SP521',
#  'ENSG00000273966': '',
#  'ENSG00000252173': 'RNU6-109P',
#  'ENSG00000252323': 'RNU6-184P',
#  'ENSG00000169953': 'HSFY2',
#  'ENSG00000236429': 'GPM6BP2',
#  'ENSG00000249501': 'USP9YP2',
#  'ENSG00000228193': 'ELOCP14',
#  'ENSG00000248573': 'PRYP6',
#  'ENSG00000230904': 'XKRYP2',
#  'ENSG00000238135': 'USP9YP10',
#  'ENSG00000224151': 'USP9YP28',
#  'ENSG00000251970': 'RNU1-41P',
#  'ENSG00000238088': 'OFD1P7Y',
#  'ENSG00000217179': 'MTCYBP2',
#  'ENSG00000217896': 'ZNF839P1',
#  'ENSG00000185275': 'CD24P4',
#  'ENSG00000252766': 'RNU6-255P',
#  'ENSG00000274282': '',
#  'ENSG00000234529': 'GAPDHP19',
#  'ENSG00000238191': 'CLUHP1',
#  'ENSG00000226353': 'TAF9P1',
#  'ENSG00000275578': '',
#  'ENSG00000226449': 'CDY5P',
#  'ENSG00000225896': 'ELOCP36',
#  'ENSG00000224166': 'PRYP1',
#  'ENSG00000229129': 'ACTG1P2',
#  'ENSG00000223555': 'USP9YP23',
#  'ENSG00000235521': 'USP9YP27',
#  'ENSG00000252513': 'RNU1-128P',
#  'ENSG00000224964': 'TRAPPC2P3',
#  'ENSG00000226011': 'OFD1P1Y',
#  'ENSG00000225740': 'ELOCP6',
#  'ENSG00000229138': 'CDY6P',
#  'ENSG00000224485': 'USP9YP7',
#  'ENSG00000226116': 'USP9YP6',
#  'ENSG00000237558': 'CDY7P',
#  'ENSG00000233378': 'USP9YP34',
#  'ENSG00000237616': 'USP9YP32',
#  'ENSG00000224033': 'CDY8P',
#  'ENSG00000230412': 'ELOCP12',
#  'ENSG00000225895': 'TRAPPC2P8',
#  'ENSG00000233120': 'USP9YP15',
#  'ENSG00000252166': 'RNU1-95P',
#  'ENSG00000232744': 'USP9YP16',
#  'ENSG00000229465': 'ACTG1P11',
#  'ENSG00000231311': 'PRYP2',
#  'ENSG00000236599': 'ELOCP26',
#  'ENSG00000232899': 'CDY9P',
#  'ENSG00000229302': 'TAF9P2',
#  'ENSG00000228945': 'CLUHP2',
#  'ENSG00000233522': 'FAM224A',
#  'ENSG00000278391': '',
#  'ENSG00000251953': 'RNA5SP522',
#  'ENSG00000252667': 'RNA5SP523',
#  'ENSG00000249726': 'TUBB1P1',
#  'ENSG00000225716': 'ELOCP13',
#  'ENSG00000229406': 'OFD1P4Y',
#  'ENSG00000227494': 'USP9YP14',
#  'ENSG00000252209': 'RNU1-48P',
#  'ENSG00000249634': 'USP9YP5',
#  'ENSG00000251510': '',
#  'ENSG00000238067': 'XKRYP1',
#  'ENSG00000233546': 'PRYP5',
#  'ENSG00000230377': 'ELOCP7',
#  'ENSG00000250951': 'USP9YP1',
#  'ENSG00000230458': 'GPM6BP1',
#  'ENSG00000131007': 'TTTY9B',
#  'ENSG00000235479': 'RAB9AP4',
#  'ENSG00000249606': 'TRAPPC2P7',
#  'ENSG00000176728': 'TTTY14',
#  'ENSG00000267793': '',
#  'ENSG00000260197': '',
#  'ENSG00000288049': '',
#  'ENSG00000012817': 'KDM5D',
#  'ENSG00000172468': 'HSFY1',
#  'ENSG00000176679': 'TGIF2LY',
#  'ENSG00000169800': 'RBMY1F',
#  'ENSG00000182415': 'CDY2A',
#  'ENSG00000233126': 'ZNF736P3Y',
#  'ENSG00000227251': 'TRIM60P9Y',
#  'ENSG00000252633': 'RN7SKP282',
#  'ENSG00000251996': '',
#  'ENSG00000252155': 'RNU6-941P',
#  'ENSG00000252472': 'RNU6-521P',
#  'ENSG00000224953': 'SRIP3',
#  'ENSG00000274365': '',
#  'ENSG00000233634': 'GOT2P5',
#  'ENSG00000237701': 'ATP5PFP1',
#  'ENSG00000273906': '',
#  'ENSG00000232976': 'TRIM60P10Y',
#  'ENSG00000226270': 'ZNF736P2Y',
#  'ENSG00000227837': 'TRIM60P11Y',
#  'ENSG00000278602': '',
#  'ENSG00000223978': 'ZNF736P1Y',
#  'ENSG00000278197': '',
#  'ENSG00000230819': 'ZNF736P5Y',
#  'ENSG00000185894': 'BPY2C',
#  'ENSG00000228296': 'TTTY4C',
#  'ENSG00000205916': 'DAZ4',
#  'ENSG00000129873': 'CDY2B',
#  'ENSG00000251841': 'RNU6-1334P',
#  'ENSG00000184895': 'SRY',
#  'ENSG00000237659': 'RNASEH2CP1',
#  'ENSG00000232195': 'TOMM22P2',
#  'ENSG00000286130': '',
#  'ENSG00000129824': 'RPS4Y1',
#  'ENSG00000229163': 'NAP1L1P2',
#  'ENSG00000278847': '',
#  'ENSG00000067646': 'ZFY',
#  'ENSG00000233070': 'ZFY-AS1',
#  'ENSG00000223600': 'EEF1A1P41',
#  'ENSG00000215414': 'PSMA6P1',
#  'ENSG00000224035': 'SFPQP1',
#  'ENSG00000223915': 'DPPA2P1',
#  'ENSG00000067048': 'DDX3Y',
#  'ENSG00000288512': 'C1R',
#  'ENSG00000234059': 'CASKP1',
#  'ENSG00000183878': 'UTY',
#  'ENSG00000288124': 'C1RL',
#  'ENSG00000288352': 'C1RL-AS1',
#  'ENSG00000288369': 'RBP5',
#  'ENSG00000284403': 'RNU6-485P',
#  'ENSG00000288383': '',
#  'ENSG00000288427': 'CLSTN3',
#  'ENSG00000288281': '',
#  'ENSG00000288116': '',
#  'ENSG00000288217': 'PEX5',
#  'ENSG00000154620': 'TMSB4Y',
#  'ENSG00000129864': 'VCY',
#  'ENSG00000187191': 'DAZ3',
#  'ENSG00000188120': 'DAZ1',
#  'ENSG00000205936': 'PPP1R12BP2',
#  'ENSG00000251925': '',
#  'ENSG00000286744': '',
#  'ENSG00000225189': 'REREP1Y',
#  'ENSG00000230073': '',
#  'ENSG00000236647': '',
#  'ENSG00000099721': 'AMELY',
#  'ENSG00000092377': 'TBL1Y',
#  'ENSG00000288463': '',
#  'ENSG00000232583': 'GPR143YP',
#  'ENSG00000205944': 'DAZ2',
#  'ENSG00000226555': 'AGKP1',
#  'ENSG00000228787': 'NLGN4Y-AS1',
#  'ENSG00000242389': 'RBMY1E',
#  'ENSG00000165246': 'NLGN4Y',
#  'ENSG00000288135': '',
#  'ENSG00000288322': '',
#  'ENSG00000288356': '',
#  'ENSG00000288117': '',
#  'ENSG00000231535': 'LINC00278',
#  'ENSG00000229343': 'CDY22P',
#  'ENSG00000232695': 'ELOCP17',
#  'ENSG00000235511': 'OFD1P18Y',
#  'ENSG00000232914': 'TRAPPC2P4',
#  'ENSG00000223655': 'RAB9AP3',
#  'ENSG00000230854': 'USP9YP20',
#  'ENSG00000252625': 'RNU1-40P',
#  'ENSG00000227635': 'USP9YP21',
#  'ENSG00000237546': 'XKRYP6',
#  'ENSG00000172283': 'PRYP4',
#  'ENSG00000227867': 'ELOCP11',
#  'ENSG00000231716': 'CDY23P',
#  'ENSG00000234744': 'USP9YP26',
#  'ENSG00000233156': 'HSFY8P',
#  'ENSG00000234888': 'OFD1P15Y',
#  'ENSG00000235014': 'REREP2Y',
#  'ENSG00000289705': '',
#  'ENSG00000225876': '',
#  'ENSG00000251796': '',
#  'ENSG00000229238': 'PPP1R12BP1',
#  'ENSG00000252948': 'RNU6-1314P',
#  'ENSG00000233843': 'CYCSP48',
#  'ENSG00000188399': 'ANKRD36P1',
#  'ENSG00000277146': '',
#  'ENSG00000129862': 'VCY1B',
#  'ENSG00000235451': 'PNPLA4P1',
#  'ENSG00000289706': '',
#  'ENSG00000226611': 'OFD1P2Y',
#  'ENSG00000240438': 'OFD1P5Y',
#  'ENSG00000286247': '',
#  'ENSG00000225624': 'TBL1YP1',
#  'ENSG00000280969': 'RPS4Y2',
#  'ENSG00000224482': 'HSFY4P',
#  'ENSG00000216844': '',
#  'ENSG00000229551': 'GAPDHP17',
#  'ENSG00000226504': 'TMEM167AP1',
#  'ENSG00000254488': '',
#  'ENSG00000237427': 'TOMM22P1',
#  'ENSG00000289707': '',
#  'ENSG00000232634': 'NEFLP1',
#  'ENSG00000226918': '',
#  'ENSG00000183146': 'PRORY',
#  'ENSG00000236615': '',
#  'ENSG00000288057': '',
#  'ENSG00000237269': 'RBMY2TP',
#  'ENSG00000169849': 'TSPY14P',
#  'ENSG00000169811': 'RBMY1HP',
#  'ENSG00000242393': '',
#  'ENSG00000228257': '',
#  'ENSG00000184991': 'TTTY13',
#  'ENSG00000271123': 'ELOCP5',
#  'ENSG00000226042': 'CDY10P',
#  'ENSG00000237023': 'USP9YP3',
#  'ENSG00000229416': 'USP9YP8',
#  'ENSG00000230029': 'CDY11P',
#  'ENSG00000224169': 'HSFY6P',
#  'ENSG00000223407': 'USP9YP18',
#  'ENSG00000226873': 'CDY14P',
#  'ENSG00000227915': 'ELOCP16',
#  'ENSG00000236620': 'XKRYP3',
#  'ENSG00000224866': 'USP9YP25',
#  'ENSG00000232424': 'USP9YP29',
#  'ENSG00000252681': 'RNU1-97P',
#  'ENSG00000232910': 'RAB9AP1',
#  'ENSG00000232845': 'TRAPPC2P9',
#  'ENSG00000237302': 'OFD1P11Y',
#  'ENSG00000169763': 'PRYP3',
#  'ENSG00000277930': '',
#  'ENSG00000252468': 'RNU2-57P',
#  'ENSG00000231341': 'VDAC1P6',
#  'ENSG00000235001': 'EIF4A1P2',
#  'ENSG00000214207': 'KRT18P10',
#  'ENSG00000278585': 'SNX3P1Y',
#  'ENSG00000235175': 'RPL26P37',
#  'ENSG00000099715': 'PCDH11Y',
#  'ENSG00000225466': 'OFD1P10Y',
#  'ENSG00000231540': 'ELOCP9',
#  'ENSG00000223362': 'CDY15P',
#  'ENSG00000231026': 'XKRYP4',
#  'ENSG00000224571': 'USP9YP13',
#  'ENSG00000226369': 'USP9YP11',
#  'ENSG00000280961': 'TTTY3B',
#  'ENSG00000227871': 'USP9YP12',
#  'ENSG00000251917': 'RNU1-86P',
#  'ENSG00000231423': 'RAB9AP5',
#  'ENSG00000228465': 'TRAPPC2P10',
#  'ENSG00000232585': 'OFD1P12Y',
#  'ENSG00000234081': 'ELOCP10',
#  'ENSG00000172352': 'CDY1B',
#  'ENSG00000231375': 'CDY17P',
#  'ENSG00000237467': 'USP9YP35',
#  'ENSG00000229250': 'USP9YP31',
#  'ENSG00000232205': 'CDY18P',
#  'ENSG00000235981': '',
#  'ENSG00000223698': 'GOLGA6L11P',
#  'ENSG00000242854': 'DNM1P24',
#  'ENSG00000230977': '',
#  'ENSG00000244231': 'CSPG4P2Y',
#  'ENSG00000172342': 'CSPG4P3Y',
#  'ENSG00000284071': '',
#  'ENSG00000274234': 'RN7SL818P',
#  'ENSG00000225491': 'UBE2Q2P4Y',
#  'ENSG00000224827': 'LINC00265-2P',
#  'ENSG00000233740': 'CICP2',
#  'ENSG00000248792': 'SEPTIN14P22',
#  'ENSG00000279274': '',
#  'ENSG00000234399': 'RBMY2XP',
#  'ENSG00000227439': 'TTTY17B',
#  'ENSG00000224210': 'TRIM60P5Y',
#  'ENSG00000232003': 'ZNF736P12Y',
#  'ENSG00000235412': 'TTTY4B',
#  'ENSG00000183795': 'BPY2B',
#  'ENSG00000240566': '',
#  'ENSG00000236379': 'ZNF736P4Y',
#  'ENSG00000274899': '',
#  'ENSG00000223641': 'TTTY17C',
#  'ENSG00000227633': 'RBMY2YP',
#  'ENSG00000279115': '',
#  'ENSG00000233652': 'CICP1',
#  'ENSG00000233944': 'LINC00265-3P',
#  'ENSG00000223636': 'UBE2Q2P5Y',
#  'ENSG00000172297': 'GOLGA2P3Y',
#  'ENSG00000278242': 'RN7SL725P',
#  'ENSG00000284380': '',
#  'ENSG00000172294': 'CSPG4P4Y',
#  'ENSG00000240450': 'CSPG4P1Y',
#  'ENSG00000239304': 'DNM1P48',
#  'ENSG00000233619': '',
#  'ENSG00000197092': 'GOLGA6L16P',
#  'ENSG00000235583': '',
#  'ENSG00000237823': 'CDY19P',
#  'ENSG00000229709': 'USP9YP36',
#  'ENSG00000232064': 'USP9YP33',
#  'ENSG00000225609': 'CDY20P',
#  'ENSG00000270535': 'ELOCP34',
#  'ENSG00000225287': 'OFD1P13Y',
#  'ENSG00000225256': 'TRAPPC2P5',
#  'ENSG00000223856': 'RAB9AP2',
#  'ENSG00000235004': 'USP9YP30',
#  'ENSG00000252426': 'RNU1-107P',
#  'ENSG00000231141': 'TTTY3',
#  'ENSG00000232614': 'USP9YP9',
#  'ENSG00000225326': 'USP9YP19',
#  'ENSG00000223406': 'XKRYP5',
#  'ENSG00000215506': 'TPTE2P4',
#  'ENSG00000224240': 'CYCSP49',
#  'ENSG00000227629': 'SLC25A15P1',
#  'ENSG00000237917': 'PARP4P1',
#  'ENSG00000231514': 'CCNQP2',
#  'ENSG00000172288': 'CDY1',
#  'ENSG00000226941': 'RBMY1J',
#  'ENSG00000289826': '',
#  'ENSG00000242875': 'RBMY1B',
#  'ENSG00000234414': 'RBMY1A1',
#  'ENSG00000234795': 'RFTN1P1',
#  'ENSG00000290323': 'TTTY16',
#  'ENSG00000243040': 'RBMY2FP',
#  'ENSG00000290336': '',
#  'ENSG00000173357': '',
#  'ENSG00000290342': '',
#  'ENSG00000224657': 'RBMY2BP',
#  'ENSG00000290348': '',
#  'ENSG00000180910': 'TTTY11',
#  'ENSG00000290381': 'TTTY11',
#  'ENSG00000224060': 'ARSLP1',
#  'ENSG00000290435': '',
#  'ENSG00000242153': 'OFD1P6Y',
#  'ENSG00000290716': 'TTTY9A',
#  'ENSG00000250868': 'XKRY',
#  'ENSG00000290724': 'XKRY',
#  'ENSG00000244646': 'XKRYP7',
#  'ENSG00000282909': '',
#  'ENSG00000288686': '',
#  'ENSG00000290840': 'XGY2',
#  'ENSG00000227289': 'HSFY3P',
#  'ENSG00000290841': '',
#  'ENSG00000235462': 'TAB3P1',
#  'ENSG00000290852': '',
#  'ENSG00000241859': 'ANOS2P',
#  'ENSG00000290853': '',
#  'ENSG00000223637': 'RBMY2EP',
#  'ENSG00000290954': '',
#  'ENSG00000239533': 'GOLGA2P2Y',
#  'ENSG00000291016': 'GOLGA2P2Y',
#  'ENSG00000278212': '',
#  'ENSG00000291032': '',
#  'ENSG00000131002': 'TXLNGY',
#  'ENSG00000291033': '',
#  'ENSG00000206159': 'GYG2P1',
#  'ENSG00000291034': '',
#  'ENSG00000232235': 'CDY3P',
#  'ENSG00000224408': 'USP9YP22',
#  'ENSG00000238154': 'USP9YP4',
#  'ENSG00000232924': 'ELOCP4',
#  'ENSG00000197038': 'RBMY1A3P',
#  'ENSG00000275310': '',
#  'ENSG00000232808': 'TTTY20',
#  'ENSG00000233803': 'TSPY4',
#  'ENSG00000228383': 'FAM197Y7',
#  'ENSG00000286120': '',
#  'ENSG00000188656': 'TSPY7P',
#  'ENSG00000237802': 'FAM197Y6',
#  'ENSG00000286173': '',
#  'ENSG00000229549': 'TSPY8',
#  'ENSG00000228927': 'TSPY3',
#  'ENSG00000284255': 'OR4C12',
#  'ENSG00000215540': 'RBMY2CP',
#  'ENSG00000284278': 'OR4C48P',
#  'ENSG00000284123': 'OR4C49P',
#  'ENSG00000292249': 'OR4C45',
#  'ENSG00000293249': '',
#  'ENSG00000215507': 'RBMY2DP',
#  'ENSG00000293280': '',
#  'ENSG00000239893': 'ZNF736P9Y',
#  'ENSG00000293305': '',
#  'ENSG00000225560': 'FAM197Y8',
#  'ENSG00000099725': 'PRKY',
#  'ENSG00000293442': '',
#  'ENSG00000228786': 'SEPTIN14P23',
#  'ENSG00000290725': 'XKRYP7',
#  'ENSG00000290726': 'FAM41AY2',
#  'ENSG00000291031': '',
#  'ENSG00000215580': 'BCORP1',
#  'ENSG00000293362': 'FAM197Y8',
#  'ENSG00000290330': 'FAM197Y5',
#  'ENSG00000225516': 'FAM197Y5',
#  'ENSG00000258992': 'TSPY1',
#  'ENSG00000290373': 'FAM197Y4',
#  'ENSG00000274196': 'FAM197Y4',
#  'ENSG00000238074': 'TSPY9',
#  'ENSG00000290607': 'FAM197Y3',
#  'ENSG00000230066': 'FAM197Y3',
#  'ENSG00000270073': 'TSPY6P',
#  'ENSG00000290332': '',
#  'ENSG00000234803': 'FAM197Y2',
#  'ENSG00000236424': 'TSPY10',
#  'ENSG00000224336': 'FAM197Y1',
#  'ENSG00000236786': 'TSPY15P',
#  'ENSG00000231436': 'RBMY3AP',
#  'ENSG00000234110': 'TSPY25P',
#  'ENSG00000226223': 'TSPY16P',
#  'ENSG00000232617': '',
#  'ENSG00000183385': 'TTTY8',
#  'ENSG00000147761': 'TTTY7B',
#  'ENSG00000212855': 'TTTY2',
#  'ENSG00000129845': 'TTTY1',
#  'ENSG00000224075': 'TTTY22',
#  'ENSG00000228379': '',
#  'ENSG00000229208': 'RBMY2NP',
#  'ENSG00000274445': '',
#  'ENSG00000231874': 'TSPY18P',
#  'ENSG00000187657': 'TSPY13P',
#  'ENSG00000239225': 'TTTY23',
#  'ENSG00000234950': 'RBMY2OP',
#  'ENSG00000290344': '',
#  'ENSG00000236718': 'RBMY2QP',
#  'ENSG00000243643': 'TSPY20P',
#  'ENSG00000290378': '',
#  'ENSG00000225685': 'TSPY5P',
#  'ENSG00000278478': '',
#  'ENSG00000251766': 'RNA5SP518',
#  'ENSG00000252289': 'RNA5SP519',
#  'ENSG00000231411': 'DUX4L31',
#  'ENSG00000226061': 'PCMTD1P1',
#  'ENSG00000237447': 'CDC27P2',
#  'ENSG00000225840': '',
#  'ENSG00000251705': 'RNA5-8SP6',
#  'ENSG00000237195': 'DLGAP5P1',
#  'ENSG00000290369': 'TTTY23B',
#  'ENSG00000250204': 'TTTY23B',
#  'ENSG00000168757': 'TSPY2',
#  'ENSG00000290448': 'FAM197Y9',
#  'ENSG00000234830': 'FAM197Y9',
#  'ENSG00000238235': 'TSPY11P',
#  'ENSG00000275352': '',
#  'ENSG00000234583': 'TSPY19P',
#  'ENSG00000235094': '',
#  'ENSG00000223744': 'RBMY2GP',
#  'ENSG00000229643': 'LINC00280',
#  'ENSG00000129816': 'TTTY1B',
#  'ENSG00000212856': 'TTTY2B',
#  'ENSG00000147753': 'TTTY7',
#  'ENSG00000185700': 'TTTY8B',
#  'ENSG00000235895': '',
#  'ENSG00000232620': 'TSPY17P',
#  'ENSG00000280963': 'SERTAD4-AS1',
#  'ENSG00000281230': 'SERTAD4',
#  'ENSG00000281067': 'ST13P19',
#  'ENSG00000281552': '',
#  'ENSG00000285063': 'FRG2',
#  'ENSG00000280680': 'HHAT',
#  'ENSG00000283153': 'FRG1',
#  'ENSG00000283508': 'MLLT10P2',
#  'ENSG00000283127': '',
#  'ENSG00000283593': 'TUBB7P',
#  'ENSG00000283700': 'RNA5SP174',
#  'ENSG00000283581': 'RNA5SP175',
#  'ENSG00000283181': 'DUX4L9',
#  'ENSG00000283449': 'RARRES2P4',
#  'ENSG00000284383': '',
#  'ENSG00000284496': '',
#  'ENSG00000284262': '',
#  'ENSG00000283767': '',
#  'ENSG00000284210': '',
#  'ENSG00000283884': '',
#  'ENSG00000283955': '',
#  'ENSG00000284025': '',
#  'ENSG00000283878': '',
#  'ENSG00000284181': '',
#  'ENSG00000283820': '',
#  'ENSG00000283660': 'RPL23AP84',
#  'ENSG00000292263': '',
#  'ENSG00000283363': 'DUX4L8',
#  'ENSG00000283949': 'DUX4',
#  'ENSG00000287371': '',
#  'ENSG00000281499': 'RNU5A-8P',
#  'ENSG00000287648': '',
#  'ENSG00000280937': 'BPNT2P1',
#  'ENSG00000280584': 'OBP2B',
#  'ENSG00000280820': 'LCN1P1',
#  'ENSG00000280632': '',
#  'ENSG00000281430': 'LCN1P2',
#  'ENSG00000281309': 'SURF6',
#  'ENSG00000281393': '',
#  'ENSG00000281022': 'MED22',
#  'ENSG00000281699': 'RPL21P81',
#  'ENSG00000280858': 'RPL7A',
#  'ENSG00000280889': 'SNORD24',
#  'ENSG00000281243': 'SNORD36B',
#  'ENSG00000281907': 'SNORD36A',
#  'ENSG00000283984': '',
#  'ENSG00000281541': 'SNORD36C',
#  'ENSG00000280627': 'SURF1',
#  'ENSG00000286057': '',
#  'ENSG00000286146': '',
#  'ENSG00000278678': 'CYCSP41',
#  'ENSG00000279647': '',
#  'ENSG00000281024': 'SURF2',
#  'ENSG00000280372': '',
#  'ENSG00000179381': 'OR4K11P',
#  'ENSG00000278931': '',
#  'ENSG00000286148': '',
#  'ENSG00000280436': '',
#  'ENSG00000280951': 'SURF4',
#  'ENSG00000279720': 'SOWAHCP2',
#  'ENSG00000279477': '',
#  ...}

# %%
# counts 인덱스에 맞는 map_dict의 Genesymbol을 매핑

counts['GeneSymbol'] = counts.index.map(map_dict)
print(f'Count of rows: {counts.shape[0]}')
# Out:
# Count of rows: 65217

# %%
# Gene Symbol이 없는 EnsembleID는 삭제

counts.dropna(subset=['GeneSymbol'], inplace=True)
print(f'Count of rows: {counts.shape[0]}')
# Out:
# Count of rows: 60466

# %%
# Gene Symbol열에 공백인 행 발견함
counts = counts[counts['GeneSymbol']!='']
print(f'Count of rows: {counts.shape[0]}')
# Out:
# Count of rows: 43369

# %%
# 'GeneSymbol' 컬럼을 인덱스로 설정하고 'EnsembleID' 컬럼 삭제

counts.set_index('GeneSymbol', inplace=True)
print(f'The shape of counts table: {counts.shape}')
# Out:
# The shape of counts table: (43369, 40)

# %% [markdown]
# ## 이슈 (해결)
# 매핑하면서 Ensembl ID에서 공동으로 매핑되는 GeneSymbol이 존재함.
# -> Sum 값 활용

# %%
my_list = counts.columns.tolist()

common_items = set()

for item in my_list:
    if my_list.count(item) > 1:  # 리스트에서 해당 아이템이 두 번 이상 나타나면
        common_items.add(item)   # 공통 아이템 세트에 추가

# %%
counts[common_items]
# Out:
# Empty DataFrame
# Columns: []
# Index: [TSPAN6, TNMD, DPM1, SCYL3, FIRRM, FGR, CFH, FUCA2, GCLC, NFYA, STPG1, NIPAL3, LAS1L, ENPP4, SEMA3F, CFTR, ANKIB1, CYP51A1, KRIT1, RAD52, MYH16, BAD, LAP3, CD99, HS3ST1, AOC1, WNT16, HECW1, MAD1L1, LASP1, SNX11, TMEM176A, M6PR, KLHL13, CYP26B1, ICA1, DBNDD1, ALS2, CASP10, CFLAR, TFPI, NDUFAF7, RBM5, MTMR7, SLC7A2, ARF5, SARM1, POLDIP2, PLXND1, AK2, CD38, FKBP4, KDM1A, RBM6, CAMKK1, RECQL, VPS50, HSPB6, ARHGAP33, NDUFAB1, PDK4, SLC22A16, ZMYND10, ABCB5, ARX, SLC25A13, ST7, CDC27, SLC4A1, CALCR, HCCS, DVL2, PRSS22, UPF1, SKAP2, SLC25A5, MCUB, HOXA11, POLR2J, DHX33, MEOX1, THSD7A, LIG3, RPAP3, ACSM3, REXO5, CIAPIN1, SPPL2B, ATOSB, COPZ2, PRKAR2B, MSL3, CREBBP, TSPOAP1, MPO, PON1, GCFC2, WDR54, CROT, ABCB4, ...]
#
# [43369 rows x 0 columns]

# %%
print(f'원 데이터: {counts.shape}')
counts = counts.groupby(counts.index).sum()
print(f'공동 유전자 sum: {counts.shape}')
counts.head()
# Out:
# 원 데이터: (43369, 40)
# 공동 유전자 sum: (40063, 40)
#             Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# GeneSymbol
# A1BG               0         7         0         1         5         3
# A1BG-AS1          14        13         3        17        18        21
# A1CF               1         1         2         4         0         0
# A2M             7145      9004      3427      6806      6684      8837
# A2M-AS1          131       111        65       168       129       160
#
#             Sample 7  Sample 8  Sample 9  Sample 10  ...  Sample 31  \
# GeneSymbol                                           ...
# A1BG               3         3         0          4  ...          7
# A1BG-AS1           7        12        12         26  ...         16
# A1CF               3         2         0          1  ...          0
# A2M             7772      7157      5560       6838  ...       6439
# A2M-AS1          204       154       159        136  ...        112
#
#             Sample 32  Sample 33  Sample 34  Sample 35  Sample 36  Sample 37  \
# GeneSymbol
# A1BG                5          1          1          4          2          2
# A1BG-AS1           13         10          2         13         16         12
# A1CF                0          0          0          1          3          1
# A2M              7099       5109       3326       5538       8194       6718
# A2M-AS1           138        134        101        135        163        141
#
#             Sample 38  Sample 39  Sample 40
# GeneSymbol
# A1BG                3          2          2
# A1BG-AS1           17         24          9
# A1CF                1          2          1
# A2M              8848       7610       5369
# A2M-AS1           148        133         93
#
# [5 rows x 40 columns]

# %%
counts = counts.transpose()

# %%
# raw 저장
# metadata.to_csv('./GSE111016_metadata.csv', sep='\t')
# counts.to_csv('./GSE111016_counts.csv', sep='\t')

# %% [markdown]
# ## Ensembl to Symbol (by sambomics)

# %%
# # sanbomics.tools의 id_map 모듈을 활용하여 매핑할 수 있습니다. 
# mapper = id_map(species = 'human', key = 'ensembl', target = 'symbol')

# %%
# # counts 데이터프레임의 Index를 gene symbol로 바꿔줍니다.
# counts['Symbol'] = counts.index.map(mapper.mapper)
# counts.head()
# Out:
#                  Sample 1  Sample 2  Sample 3  Sample 4  Sample 5  Sample 6  \
# ENSG00000000003       124       145        61       110       122       120
# ENSG00000000005         7         6        10        16       124         9
# ENSG00000000419       536       839       415       690       825       852
# ENSG00000000457       402       538       244       486       538       549
# ENSG00000000460       141       119        73       169        96       104
#
#                  Sample 7  Sample 8  Sample 9  Sample 10  ...  Sample 32  \
# ENSG00000000003       145       118       108        125  ...        119
# ENSG00000000005        37         3         6         45  ...          3
# ENSG00000000419       774       838       629        708  ...        739
# ENSG00000000457       629       525       430        453  ...        405
# ENSG00000000460       145       115        94        131  ...        104
#
#                  Sample 33  Sample 34  Sample 35  Sample 36  Sample 37  \
# ENSG00000000003         79         67        134        114        106
# ENSG00000000005          6         35          5         16          8
# ENSG00000000419        639        462        780        551        576
# ENSG00000000457        431        292        494        443        395
# ENSG00000000460        145         85        131        115        141
#
#                  Sample 38  Sample 39  Sample 40    Symbol
# ENSG00000000003        128        149        122    TSPAN6
# ENSG00000000005          6         27         18      TNMD
# ENSG00000000419        788        742        656      DPM1
# ENSG00000000457        551        483        438     SCYL3
# ENSG00000000460        121        125        120  C1orf112
#
# [5 rows x 41 columns]

# %%
# # 몇 개의 유전자가 매핑되었는지 확인해봅니다.
# print(f'The shape of counts Dataframe: {counts.shape}')
# counts['Symbol'].isnull().value_counts()
# Out:
# The shape of counts Dataframe: (65217, 41)
# False    51332
# True     13885
# Name: Symbol, dtype: int64

# %% [markdown]
# ## Filtering genes

# %%
counts = counts.T

# %%
# 전체 샘플에서 발현량이 없는 유전자를 필터링합니다.
print(f'필터링 전 테이블: {counts.shape}')
counts = counts[counts.sum(axis=1)>0]
print(f'필터링 후 테이블: {counts.shape}')
# Out:
# 필터링 전 테이블: (40063, 40)
# 필터링 후 테이블: (36678, 40)

# %%
# 논문 상 필터링 기준
counts = counts[counts.mean(axis=1)>20]
print(f'논문기반 필터링 후 테이블: {counts.shape}')
# Out:
# 논문기반 필터링 후 테이블: (15357, 40)

# %%
counts = counts.transpose()
counts.head()
# Out:
# GeneSymbol   A2M  A2M-AS1  A2ML1  A4GALT  AAAS  AACS  AADAT  AAGAB  AAK1  \
# Sample 1    7145      131      5     186   593   172    103    724  1792
# Sample 2    9004      111     16     177   592   253     93    912  2333
# Sample 3    3427       65    160      85   330   154     44    434  1488
# Sample 4    6806      168      6     161   582   149     91    880  1963
# Sample 5    6684      129      8     307   559   248     91    917  2257
#
# GeneSymbol  AAMDC  ...  ZUP1  ZW10  ZWILCH  ZXDA  ZXDB  ZXDC  ZYG11B  ZYX  \
# Sample 1     1607  ...   118   682      96   346   394  1877   15055  573
# Sample 2     2208  ...   194   753     101   418   413  1866   17429  634
# Sample 3     1042  ...    66   329      61   187   196   777    7547  233
# Sample 4     1623  ...   144   796     105   331   422  1828   11336  581
# Sample 5     1558  ...   181   665     133   380   407  1762   16293  527
#
# GeneSymbol  ZZEF1  ZZZ3
# Sample 1     3175  1338
# Sample 2     3038  1454
# Sample 3     1429   642
# Sample 4     2653  1643
# Sample 5     3087  1734
#
# [5 rows x 15357 columns]

# %%
# counts.to_csv('./GSE111016_counts_filtered.csv', sep='\t')

# %% [markdown]
# # DEG analysis

# %%
# raw 읽어오기
metadata = pd.read_csv('./GSE111016_metadata.csv', sep='\t', index_col=[0])
counts = pd.read_csv('./GSE111016_counts_filtered.csv', sep='\t', index_col=[0], low_memory=False)

# %%
def my_deseq(metadata, counts, name):
    # 1. Build DeseqDataSet
    dds = DeseqDataSet(counts=counts,
                       metadata=metadata,
                       design_factors="Condition",
                       refit_cooks=True)
    
    # 2. Run DEseq2
    dds.deseq2()
    
    # 3. Deseq2Stat # 1:'os', 2:'oh'
    group1 = dds.obs.Condition.unique()[1] # 1: 'os'
    group2 = dds.obs.Condition.unique()[0] # 0: 'oh'
    print(f"comparison between {group1} and {group2}")
    
    stat_res = DeseqStats(dds, contrast=('Condition', group1, group2))
    stat_res.summary()
    res = stat_res.results_df

    # 4. Save dds and res as pickle and csv, respectively
    with open(f"./{name.split('_')[1]}/results_{name}_dds.pkl", 'wb') as f:
        pickle.dump(dds, f)
    res.to_csv(f"./{name.split('_')[1]}/results_{name}.csv")

# %%
my_deseq(metadata, counts, 'GSE111016_osoh_filtered_refit')
# Out:
# Fitting size factors...
# ... done in 0.03 seconds.
#
# Fitting dispersions...
# ... done in 5.10 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.57 seconds.
#
# Fitting MAP dispersions...
# ... done in 6.01 seconds.
#
# Fitting LFCs...
# ... done in 2.33 seconds.
#
# Replacing 82 outlier genes.
#
# Fitting dispersions...
# ... done in 0.05 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.06 seconds.
#
# Fitting LFCs...
# ... done in 0.05 seconds.
#
# Running Wald tests...
# comparison between OS and OH
# ... done in 0.98 seconds.
# Log2 fold change & Wald test p-value: Condition OS vs OH
#              baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# A2M       6659.963434       -0.188394  0.083747 -2.249562  0.024477  0.214547
# A2M-AS1    123.823629       -0.001157  0.084789 -0.013645  0.989113       NaN
# A2ML1       11.030964        0.395696  0.426042  0.928772  0.353007       NaN
# A4GALT     206.737365        0.161064  0.106277  1.515517  0.129642       NaN
# AAAS       562.242181        0.032603  0.043561  0.748452  0.454188  0.743050
# ...               ...             ...       ...       ...       ...       ...
# ZXDC      1664.379073        0.114611  0.047863  2.394569  0.016640  0.188466
# ZYG11B   13204.512796       -0.136301  0.060581 -2.249909  0.024455  0.214547
# ZYX        596.301319        0.147968  0.098065  1.508877  0.131330  0.448803
# ZZEF1     2829.319141        0.093573  0.040800  2.293480  0.021820  0.207952
# ZZZ3      1333.699151        0.016783  0.043503  0.385785  0.699656  0.879382
#
# [15357 rows x 6 columns]

# %% [markdown]
# # GSEA
# * (코멘트) gsea html 파일이 나옴! gmt, tms, gct 파일 input
# * GO에 대한 유전자 score에 따른 정보 나옴

# %%
res.head()
res['Symbol'] = res.index

# %%
ranking = res[['Symbol','stat']].dropna().sort_values('stat', ascending=False)
ranking = ranking.drop_duplicates('Symbol')
ranking

# %%
manual_set = {'things':['COL19A1', 'H19', 'FGF7', 'NHLH2', 'MT2A']}

# %%
del ranking['Symbol']

# %%
pre_res = gp.prerank(rnk = ranking,
                     gene_sets = ['GO_Biological_Process_2021', manual_set],
                     seed = 6, permutation_num = 100)

# %%
out = []

for term in list(pre_res.results):
    out.append([term,
               pre_res.results[term]['fdr'],
               pre_res.results[term]['es'],
               pre_res.results[term]['nes']])

out_df = pd.DataFrame(out, columns = ['Term','fdr', 'es', 'nes']).sort_values('fdr').reset_index(drop = True)
out_df

# %%
print(out_df.sort_values('nes').iloc[0].Term)
print(out_df.sort_values('nes').iloc[1].Term)

# %%
my_term = out_df.sort_values('nes').iloc[0].Term
my_term

# %%
gseaplot(rank_metric=pre_res.ranking, term=my_term, **pre_res.results[my_term])
